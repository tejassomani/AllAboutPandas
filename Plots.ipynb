# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(2,3,'o')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
plt.plot(3, 2, '.')
ax = plt.gca()
#xmin, xmax, ymin, ymax
ax.axis([0,5,0,5])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 5, 0, 5]

# %%
import numpy as np
x = np.array([1,2,3,4,5,6,7])
y = x ** 2

plt.figure()
plt.scatter(x[:3], y[:3], c='r', s=100, label='Red')
plt.scatter(x[3:], y[3:], c='g', s=100, label='Blue')
plt.legend()
plt.xlabel("X")
plt.ylabel("Y")
#ax = plt.gca()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## Line Charts

fig = plt.figure()
linear_data = np.array([1,2,3,4,5,6,7])
exp_data = linear_data ** 2

plt.plot(linear_data, '-o', exp_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
print(range(len(linear_data)))

# %%
plt.fill_between(range(len(linear_data)), linear_data, exp_data, color='y')

# %%
### Bar charts

plt.figure()
xvals = range(len(linear_data))
#print(xvals)
plt.bar?
plt.bar(xvals, linear_data, width = 0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 7 artists>

# %%
new_xvals = []

# plot another set of bars, adjusting the new xvals to make up for the first set of bars plotted
for item in xvals:
    new_xvals.append(item+0.3)

plt.bar(new_xvals, exp_data, width = 0.3 ,color='red')
# Out:
# <Container object of 7 artists>

# %%
## Sub plots

fig = plt.figure()
ax1 = plt.subplot(1,2,1)

plt.plot(linear_data, '-0')

##both the subplots, share the same y-axis 
plt.subplot(1,2,2, sharey=ax1)
plt.plot(exp_data, '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, sharex=True, sharey=True)

ax5.plot(linear_data, '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %%
plt.gcf().canvas.draw()

# %%
## Histogram

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1, ax2, ax3, ax4]

#distribution for n = 10, 100, 1000, 10000 sample size
for n in range(0,4):
    ## take squares
    sample_size = 10**(n+1) 
    sample = np.random.normal(loc=0.0, scale=1.1, size=sample_size)
    axs[n].hist(sample, bins=100)
    axs[n].set_title("n = {}".format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gsp = gspec.GridSpec(3,3)

top_right = plt.subplot(gsp[0, 1:])
bottom_left = plt.subplot(gsp[1:4, 0])
bottom_right = plt.subplot(gsp[1:, 1:])

X = np.random.normal(loc=0.0, scale=1.0, size=1000)
Y = np.random.random(size=1000)

bottom_right.scatter(X, Y)
top_right.hist(X, bins=100)
bottom_left.hist(Y, bins=100, orientation='horizontal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([ 13.,  12.,  11.,  10.,  12.,   5.,   7.,  12.,  12.,   9.,   5.,
#          17.,  15.,  13.,  14.,  14.,  13.,   5.,   5.,   6.,  11.,  11.,
#          16.,   3.,  14.,  17.,   3.,  11.,   9.,   7.,   8.,   9.,   8.,
#          12.,   9.,   5.,  16.,  12.,  12.,   9.,   7.,  15.,  11.,   7.,
#           9.,  14.,  12.,   7.,   6.,   8.,  11.,   7.,   9.,   9.,  11.,
#          16.,   8.,  10.,   7.,  13.,  12.,   8.,  19.,  11.,  10.,   7.,
#           9.,   9.,   7.,  12.,   5.,  12.,  11.,  13.,   9.,   9.,  11.,
#           5.,   8.,  13.,   6.,  20.,  13.,  14.,   7.,   8.,   7.,   9.,
#           9.,   9.,   7.,   8.,   6.,  11.,  12.,   5.,   7.,  16.,   8.,
#           9.]), array([  4.71616818e-04,   1.04431329e-02,   2.04146489e-02,
#           3.03861650e-02,   4.03576810e-02,   5.03291971e-02,
#           6.03007132e-02,   7.02722292e-02,   8.02437453e-02,
# ...

# %%
#### Box Plots
import pandas as pd

normal = np.random.normal(loc=0.0, scale=1.0, size=1000)
random = np.random.random(size=1000)
gamma = np.random.gamma(2, size=1000)

# %%
df = pd.DataFrame({'normal': normal, 'random':random, 'gamma': gamma})

# %%
plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'boxes': [<matplotlib.lines.Line2D at 0x137229f28>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x137239940>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x137241b70>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x137241358>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x1372338d0>,
# ...
#   <matplotlib.lines.Line2D at 0x137265d30>]}

# %%
plt.figure()
plt.hist(df['normal'], bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  1.,   1.,   0.,   0.,   0.,   0.,   1.,   1.,   2.,   1.,   2.,
#           0.,   2.,   1.,   6.,   9.,   2.,   3.,   3.,   7.,  11.,   6.,
#          10.,  10.,  10.,  10.,  14.,  12.,  12.,   8.,  18.,  13.,  18.,
#          17.,  19.,  17.,  21.,  18.,  34.,  17.,  23.,  21.,  23.,  16.,
#          27.,  20.,  23.,  29.,  25.,  21.,  26.,  21.,  20.,  25.,  22.,
#          31.,  20.,  21.,  13.,  20.,  27.,  10.,  15.,  14.,  10.,  16.,
#          15.,  10.,   9.,   9.,  12.,   4.,   9.,   8.,   9.,   6.,   5.,
#           5.,   3.,   3.,   4.,   1.,   1.,   1.,   1.,   2.,   1.,   1.,
#           0.,   2.,   0.,   0.,   1.,   1.,   0.,   0.,   0.,   0.,   0.,
#           1.]),
#  array([-2.92354532, -2.86161812, -2.79969092, -2.73776372, -2.67583652,
#         -2.61390932, -2.55198212, -2.49005492, -2.42812772, -2.36620051,
#         -2.30427331, -2.24234611, -2.18041891, -2.11849171, -2.05656451,
# ...

# %%
import seaborn as sns
sns.set(color_codes=True)


data = np.random.normal(loc=0, scale=1.0, size=100)
fig = plt.figure()

#Univariate distribution

grid = plt.GridSpec(1, 2)

left_plot = fig.add_subplot(grid[0, :1])
sns.distplot(df['normal'])
right_plot = fig.add_subplot(grid[0, 1:], sharey=left_plot)

### Two ways to plto kernel density plot

sns.distplot(df['random'], hist=False, kde=True, label='1000 samples using distplot')
sns.kdeplot(data, label='100 samples')

sns.kdeplot(data, bw=1, label='100 samples bw 1')
sns.kdeplot(data, bw=.2, label='100 samples bw 0.2')
plt.legend()


## matplotlib & seaborn for below

##Heat maps

##KDE plots
# Out:
# <img src="data:image/png;base64,..." width="800">
# /Users/Tejas/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
## BiVariate plots

mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

sns.jointplot(x="x", y="y", data=df);
# Out:
# <img src="data:image/png;base64,..." width="600">
