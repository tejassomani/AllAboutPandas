# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from matplotlib import rcParams

pd.set_option('display.max_columns', 500)
rcParams.keys()
rcParams.update({'figure.autolayout': True})

# %%
df = pd.read_csv('Fifa/CleanedPlayers.csv')

# %%
def plot_histogram(col, xlabel, ylabel, title, size=10, bins=30):
    fig = plt.figure()

    plt.hist(df[col], bins=bins, edgecolor='b')
    plt.xlabel(xlabel, fontsize=size)
    plt.ylabel(ylabel, fontsize=size)
    plt.title(title, fontsize=size)

# %%
plot_histogram('Age', 'Age', 'No of Players', 'Player Age distribution')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
print(df['Age'].describe())
fig = plt.figure()
plt.boxplot(df['Age'], whis='range')
# Out:
# count    17981.000000
# mean        25.144541
# std          4.614272
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         28.000000
# max         47.000000
# Name: Age, dtype: float64
# <img src="data:image/png;base64,..." width="800">
# {'boxes': [<matplotlib.lines.Line2D at 0x1178d9e48>],
#  'caps': [<matplotlib.lines.Line2D at 0x11bfbf828>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11c584e10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11c5845c0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11bfef2e8>,
#   <matplotlib.lines.Line2D at 0x11bfd53c8>]}

# %%
###Target variable is wage
df['Wage_in_Euro'].describe()
# Out:
# count     17981.000000
# mean      11546.966242
# std       23080.000139
# min           0.000000
# 25%        2000.000000
# 50%        4000.000000
# 75%       12000.000000
# max      565000.000000
# Name: Wage_in_Euro, dtype: float64

# %%
plot_histogram('Wage_in_Euro', 'Wage', 'No of Players', 'Player Wage distribution', bins=50)
fg = plt.figure()
plt.boxplot(df['Wage_in_Euro'], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# {'boxes': [<matplotlib.lines.Line2D at 0x11db850f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11db8eb70>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11db93e48>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11db935f8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11db85a90>,
#   <matplotlib.lines.Line2D at 0x11db85cc0>]}

# %%
def get_first_position(col):
    c = str(col)
    pos = c.split(" ")
    return pos[0]

df['player_position'] = df['Preferred Positions'].apply(get_first_position)

# %%
df['player_position'].unique()
# Out:
# array(['ST', 'RW', 'LW', 'GK', 'CDM', 'CB', 'RM', 'CM', 'LM', 'LB', 'CAM',
#        'RB', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
def scatter_plot(x_axis, y_axis, x_label, y_label, title, category=None):
    fig, ax = plt.subplots(figsize=(10, 5))
    
    #alpha to add more transparency to the overlapping points
    #if category is not None:
    #colors = ['#2300A8', '#00A658', '#CD5C5C', '#E9967A', '#F2D7D5']
    ax.scatter(df[x_axis], df[y_axis], alpha=0.8, s=40)
    #else:
        #ax.scatter(df[x_axis], df[y_axis], alpha=0.8, s=40)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    
    ax.set_title(title)
    
    ## Remove top and right borders
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    plt.show()

# %%
scatter_plot('Age', 'Wage_in_Euro', 'age', 'wage (Euro)', 'Age vs wage distribution', 'player_position')
# Out:
# <img src="data:image/png;base64,..." width="1000">
